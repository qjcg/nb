# %% [markdown]
# # Python Programming
#
# John Gosset<br />
# June 11-15, 2018<br />
# Vigilant Global
#
# ## Day 1
#
# - Introduction
# - Roadmap
# - Course Tools (IPython, notebooks, text editors)
# - Python Fundamentals
#    - Variables & Conditionals
#    - Input & Output
#    - Strings
#    - Sequences
#    - Dictionaries
#    - Sets
#    - Iterations & Loops
#    - Functions
#    - Generators
#    - Objects / Classes
#    - Exceptions
#    - Modules / Packages
#
# ## Day 2
#
# - Introduction (continued)
# - Lexical conventions, syntax
#     - doc strings
#     - Data & Object Typ- doctests
#         - executing a suite of tests
# es, Operators
#     - sequences
#     - lists
#     - strings, formatting
#     - mappings
#     - sets
#     - special properties
#     - verifying types, comparisons
#     - indexation, slicing, and striding
#     - conditional expressions (ternary operator)
#     - Data & Object Types, Operators (continued)
# - Control Flow
#     - Hierarchy of Exceptions
# - Functions
# - More classes
#     - Inheritance
#     - Resolution of attributes
#     - Static methods
#     - Properties (property)
#     - Operator overloading
#
#
# ## Day 3
#
# - Survey of standard library
#     - os
#     - subprocess
#     - random
#     - argparse
#     - unittest
#     - Profiling, Debugging, & Testing
#
# ## Day 4 & 5
# - Developing Applications (areas of focus will depend on students' needs & interest)
#     - Standard Library & PyPI
#     - Reusing & Distributing Code
#     - Interacting with the OS
#     - Text processing
#     - Logging
#     - Networking
#     - Web Client Applications
#     - Web Server Applications
#     - Data Serialization / Persistance
#     - Databases
#     - Command-line argument parsing
# - PyPi (3rd party)
#     - PDFs (PyPDF2, reportlab)
#     - website scraping (scrapy, BeautifulSoup)
#     - matplotlib / numpy / pandas
# - Configuration management / virtual environments
# - concurrency (concurrent.futures, asyncio)
#
# ## References
#
# - OPD: [Official Python Documentation](http://docs.python.org/3/)
# - [PEP-8](http://www.python.org/dev/peps/pep-0008/)
# - [PyPi](http://pypi.python.org/)
